# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/tesouro/curso_basico_python/blob/main/Aula%202%20-%20Condicionais.ipynb)

# %% [markdown]
# # Aula 2 - Condicionais
# <div class="alert alert-block alert-info" style="border-left: 5px solid #0056b3;">
#     <h4>🎯 Objetivos de Aprendizagem da Aula</h4>
#     <ul style="margin-left: 20px;">
#     <li><b>Operadores de Comparação:</b> <code>==</code>, <code>!=</code>, <code>></code>, <code><</code>, <code>>=</code>, <code><=</code></li>
#     <li><b>Valores Booleanos:</b> O resultado de toda comparação: <code>True</code> ou <code>False</code>.</li>
#     <li><b>Operadores Lógicos:</b> Para combinar condições: <code>and</code>, <code>or</code>, <code>not</code>.</li>
#     <li><b>Estrutura Condicional:</b> A sintaxe <code>if</code>, <code>elif</code> e <code>else</code> para criar os caminhos lógicos.</li>
#     </ul>
# </div>

# %% [markdown]
# <hr style="height:3px; border-width:0; color:gray; background-color:gray">

# %% [markdown]
# ## 1. Uma breve contextualização sobre condicionais
# Nesta aula, vamos aprender um dos conceitos fundamentais da programação, que nos permite fazer programas inteligentes, que tomam decisões: condicionais.

# %%
x = int(input("Escreva um número"))

if x % 2 == 0:
  print("Esse número é par")
elif x % 2 == 1:
  print("Esse número é ímpar")

# %% [markdown]
# O programa acima pede um número para o usuário, o converte em um número inteiro e devolve para o usuário a informação se tal número é par ou ímpar.
# É válido mencionar o operador `%` (módulo), que retorna o resto de uma divisão inteira.
#
# ![image.png](attachment:8b54e04e-59af-4d10-9aa0-54dd538ef373.png)
#
# No caso de uma divisão por 2, o resto será sempre 0 se o número for par (ou seja, divisível por 2) e será 1 se o número for ímpar (ou seja, não divisível por dois).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Com isso esclarecido, vamos destrinchar como o bloco condicional em si funciona!
#
# `if` significa 'se', e essencialmente apenas roda se a condição que vem depois do "if" for verdadeira.
#
# Tente rodar a cédula abaixo:

# %%
x = 5

if x > 10: # se x for maior que 10
  print('x maior que 10')

# %% [markdown]
# Perceba que nada acontece, não há uma saída. Agora tente rodar a cédula abaixo:

# %%
y = 15

if y > 10: # se y for maior que 10
  print('y maior que 10')

# %% [markdown]
# Agora a informação apareceu, porque a condição de "x maior que 10" foi verdadeira. Nós podemos ver isso se pedirmos ao Python para imprimir as condições. A primeira condição retorna False (falso) e a segunda retorna True (verdadeiro).
#
# Esses valores True e False são chamados de valores Booleanos.

# %%
x = 5
y = 15
print("O valor de x>10 é", x>10)
print("O valor de y>10 é", y>10)

# %% [markdown]
# Então, voltando para a checagem de par ou ímpar, o python apenas retornará o que estiver dentro da condição if se o valor booleano for True.

# %%
x = 9 # experimente mudar o valor de x

if x % 2 == 0: # se isso for verdade, o programa imprime que o número é par
  print("Esse número é par")
elif x % 2 == 1: # se isso for verdade, o programa imprime que o número é ímpar
  print("Esse número é ímpar")

# %% [markdown]
# ### 1.1. Operadores de comparação
# Operadores de Comparação:
#
# `==` (É igual a?) - Ex: `status_pagamento == 'Realizado'`
#
# `!=` (É diferente de?) - Ex: `risco != 'Baixo'`
#
# `>` (Maior que) - Ex: `valor_empenho > 50000`
#
# `>=` (Maior ou igual a) - Ex: `valor_empenho >= 50000`
#
# `<` (Menor que) - Ex: `valor_empenho < 50000`
#
# `<=` (Menor ou igual a) - Ex: `valor_empenho <= 50000`

# %% [markdown]
# ### 1.2. Operadores lógicos
# E se uma decisão depender de múltiplas condições? Por exemplo, "Aprovar uma operação SE o risco for baixo E o valor estiver dentro do limite". Para isso, usamos os operadores lógicos:
#
# `and`: Verdadeiro somente se AMBAS as condições forem True.
#
# `or`: Verdadeiro se PELO MENOS UMA das condições for True.
#
# `not`: Inverte o valor Booleano (True vira False e vice-versa).
#
# Os conceitos são os mesmos das tabelas verdade no contexto da matéria de Raciocício Lógico e Matemático.
#
# ![image-2.png](attachment:image-2.png)

# %%
# Cenário de análise de crédito
score_cliente = 750
possui_inadimplencia = False

# Usando 'and'
aprovacao_automatica = score_cliente > 700 and possui_inadimplencia == False
print(f"Aprovação automática? {aprovacao_automatica}")

# Usando 'or'
alerta_manual = score_cliente < 400 or possui_inadimplencia == True
print(f"Requer análise manual? {alerta_manual}")

# Usando 'not'
# 'not possui_inadimplencia' é o mesmo que 'possui_inadimplencia == False'
cliente_adimplente = not possui_inadimplencia
print(f"Cliente está adimplente? {cliente_adimplente}")

# %% [markdown]
# ### 1.3. Exercícios de fixação
# Para os exercícios abaixo, tente antecipar qual será o resultado antes de rodar a célula.

# %%
x = 3
y = 10

# %%
print(x > 5 and y > 5)

# %%
print(x < 5 and y > 10)

# %%
print(x < 5 or y != 10)

# %%
if x > 3: 
    print("x é maior que 3")
if y > 5:
    print("y é maior que 5")

# %% [markdown]
# ## 1.4. Além do if (elif e else)
#
# Por enquanto, nós falamos primariamente sobre o if: se algo for verdadeiro, retorne alguma coisa.

# %% [markdown]
# ![image.png](attachment:9083ee63-b665-48d6-9564-eba709e917c0.png)

# %% [markdown]
# O python também possui duas outras estruturas condicionais: `elif` e `else`.
#
# Tente mudar o valor da variável `idade` abaixo:

# %%
idade = 18 # tente mudar o valor da idade aqui

if idade < 2:
  print('Você é um bebê.')
elif idade < 12:
  print('Você é uma criança.')
elif idade < 17:
  print('Você é um adolescente.')
elif idade < 65:
  print('Você é um adulto.')
else: 
  print('Você é um idoso.')

# %% [markdown]
# Perceba que você nunca retorna mais de uma saída, mesmo o programa dando 5 opções. Por quê?
#
# Quando o python roda um `if`, ele nunca vai rodar um `elif` ou `else`. Apenas quando o if não rodar, o python checa as outras opções.
# ![image.png](attachment:fdeea9a2-71a3-432d-a90e-90ad75674e90.png)

# %%
idade = 10 # tente mudar o valor da idade aqui

if idade < 2:
  print('Você é um bebê.')
elif idade < 12:
  print('Você é uma criança.')
elif idade < 17:
  print('Você é um adolescente.')
elif idade < 65:
  print('Você é um adulto.')
else: 
  print('Você é um idoso.')

# %% [markdown]
# Da mesma maneira, quando um dos elifs for verdade o python ignora tudo que vier depois.
# ![image.png](attachment:8cf1c729-afe5-4d97-9ad9-e919e6d9ba27.png)

# %%
idade = 70 # tente mudar o valor da idade aqui

if idade < 2:
  print('Você é um bebê.')
elif idade < 12:
  print('Você é uma criança.')
elif idade < 17:
  print('Você é um adolescente.')
elif idade < 65:
  print('Você é um adulto.')
else: 
  print('Você é um idoso.')

# %% [markdown]
# Por fim, o `else` apenas roda quando todos os `ifs` e `elifs` anteriores não rodarem.
# ![image.png](attachment:8139256a-5386-4b04-98ec-72fa5a7fdf73.png)

# %% [markdown]
# ## 1.5. Exercícios de fixação
# Para os exercícios abaixo, tente antecipar qual será o resultado antes de rodar a célula.

# %%
letra = "a"
y = 3
z = True

# %%
if letra in "aeiou":
    print("Letra é uma vogal")
if y >= 0:
    print("y é maior ou igual a 0")
if z:
    print("z é True")

# %%
if letra in "aeiou":
    print("Letra é uma vogal")
elif y >= 0:
    print("y é maior ou igual a 0")
elif z:
    print("z é True")

# %%
if letra == "b":
    print("letra é igual a b")
elif y >= 5:
    print("y é maior ou igual a 5")
else:
    print("nenhuma das opções anteriores rodou")

# %% [markdown]
# <hr style="height:3px; border-width:0; color:gray; background-color:gray">

# %% [markdown]
# # 2. Exercícios

# %% [markdown]
# 1. Faça um programa que pergunta a pontuação de risco do usuário (um número de 0 a 100) e retorna seu perfil de investidor, com base nas seguintes regras:
#
# 0 a 20: Conservador
#
# 21 a 50: Moderado
#
# 51 a 80: Arrojado
#
# 81 a 100: Agressivo (ou Trader)

# %% [markdown]
# 2. Peça ao usuário uma letra, e retorne se a letra foi uma vogal ou consoante.

# %% [markdown]
# 3. Faça um Programa para leitura de três notas parciais de um aluno. O programa deve calcular a média alcançada por aluno e apresentar:
# - A mensagem "Aprovado", se a média for maior ou igual a 7, com a respectiva média alcançada;
# - A mensagem "Reprovado", se a média for menor do que 7, com a respectiva média alcançada;
# - A mensagem "Aprovado com Distinção", se a média for igual a 10.

# %% [markdown]
# 4. Faça um programa no qual o usuário pode digitar um número de 3 dígitos. Retorne o número de centenas, dezenas e unidades daquele número. Por exemplo, o usuário digitar o número 237, a saída deve ser algo como:
# ```
# > O seu número possui 2 centenas, 3 dezenas e 7 unidades
# ```

# %% [markdown]
# 5. Peça ao usuário um valor inteiro para saque (ex: 478). Retorne o número de notas de R\\$100, R\\$50, R\\$20, R\\$10, R\\$5, R\\$2 e R\\$1.

# %% [markdown]
# 6. Faça um sistema de senha no qual o usuário precisa adivinhar a senha corretamente para entrar no sistema. Dê três chances para o usuário acertar a senha – após a terceira senha errada, encerre o programa e informe ao usuário "Acesso Negado".

# %% [markdown]
# <hr style="height:3px; border-width:0; color:gray; background-color:gray">

# %% [markdown]
# ## 3. Bug Hunt
# Os códigos abaixo possuem algum tipo de problema. Leia o código e a mensagem de erro atentamente e tente solucionar o bug!
# Descreva o erro e a solução com suas próprias palavras.

# %%
#3.1. Eu quero imprimir apenas uma mensagem
score = 15

if score < 80:
    print("Perfil não é Agressivo.") 
if score < 50:
    print("Perfil não é Arrojado.") 
if score < 20:
    print("Perfil é Conservador.")

# %% [markdown]
# Erro:
#
# Solução:

# %%
#3.2
x = 10

if x > 4:
    print("maior que 4")
else if x > 7:
    print("maior que 7")

# %% [markdown]
# Erro:
#
# Solução:

# %%
#3.3
modalidade_investimento = "Tesouro Direto"

if modalidade_investimento = "Tesouro Direto":
    print("Esta modalidade é considerada de baixo risco.")

# %% [markdown]
# Erro:
#
# Solução:

# %% [markdown]
# <hr style="height:3px; border-width:0; color:gray; background-color:gray">

# %% [markdown]
# # 4. Projetos para você fazer!
#
# 1. Faça uma calculadora completa de IMC: Peça ao usuário seu peso e altura. Tenha a opção de duas unidade de peso (kg e libras) e duas unidades de altura (metros e pés+polegadas). Calcule o IMC e mostre uma mensagem de saída, usando a seguinte lógica:
# - Caso o IMC resultante seja menor que 18.5, a pessoa está abaixo do peso saudável.
# - Caso o IMC resultante esteja entre 18.5 e 25, a pessoa está com o peso saudável.
# - Caso o IMC resultante esteja entre 25 e 30, a pessoa está acima do peso saudável
# - Caso o IMC resultante esteja entre 30 e 35, a pessoa está obesa.
# - Caso o IMC resultante esteja  maior que 35, a pessoa está com obesidade mórbida.
#
# **Bônus**: caso o IMC seja um valor inesperado (e.g. um valor negativo ou acima de 100), mostre uma mensagem de erro e peça para o usuário tentar novamente.

# %% [markdown]
# 2. Faça um programa que jogue pedra-papel-tesoura com o usuário.
# - O usuário escolhe pedra, papel ou tesoura
# - O computador aleatoriamente escolhe pedra, papel ou tesoura (dica: pesquise sobre `random.choice`)
# - Retorne a mensagem se o usuário ganhou, perdeu ou se deu empate.

# %% [markdown]
# <hr style="height:3px; border-width:0; color:gray; background-color:gray">

# %% [markdown]
# ## 5. Perguntas para Discussão em Grupo

# %% [markdown]
# 1) No problema do caixa eletrônico, por que é importante calcular primeiro as notas de maior valor para apenas depois calcular as cédulas de menor valor.

# %% [markdown]
# 2) Pensem em um critério de conformidade (compliance) ou uma regra de negócio do Tesouro que dependa de múltiplas condições para ser atendida (ex: "A despesa está apta para pagamento SE (o valor for menor que o limite X E a documentação estiver completa) OU (se ela tiver uma autorização especial).").
#
# Desenhe um fluxograma com as condições.

# %% [markdown]
# <hr style="height:3px; border-width:0; color:gray; background-color:gray">

# %% [markdown]
# ## 6. Sugestões de pesquisa
# Se você terminou os exercícios e deseja se aprofundar em alguns detalhes da linguagem, deixo algumas sugestões de pesquisa a serem realizadas:

# %% [markdown]
# 1) Além dos operadores que vimos (`==`, `!=`, `>`, `<`), quais são todos os operadores de comparação no Python e o que os operadores `is` e `in` fazem?

# %% [markdown]
# 2. Além de fluxogramas, quais são outras maneira de desenhar um fluxo de decisão para linguagens de programação?

# %% [markdown]
# 3) Como funciona a 'expressão condicional', também conhecida como operador ternário, em Python?

# %% [markdown]
# 4) Imagine que eu tenho uma função lenta e custosa (que vai buscar dados em um banco, por exemplo). Qual dos códigos abaixo é mais eficiente e por quê?

# %%
import time

def funcao_lenta_e_custosa():
    print("Executando função lenta")
    time.sleep(3) # simulando uma função lenta, leva 3 segundos para rodar
    print("Finalizando função lenta")
    return True

condicao = True

if funcao_lenta_e_custosa() or condicao:
    print("Opção 1")

if condicao or funcao_lenta_e_custosa():
    print("Opção 2")

# %% [markdown]
# 5) O que acontece se um usuário digita um texto quando seu programa espera um número, causando um ValueError? Pesquise sobre a estrutura try...except...finally em Python como a forma correta de capturar e lidar com erros sem que o programa 'quebre'."

# %%
try:
    idade_str = input("Digite sua idade: ")
    idade_num = int(idade_str)
    print(f"Você digitou a idade {idade_num}.")
except ValueError:
    print("Erro: O valor digitado não é um número inteiro válido.")
finally:
    print("Este bloco ('finally') é executado sempre, com ou sem erro.")

# %% [markdown]
# 6) Pesquise sobre a estrutura match-case no Python

# %% [markdown]
# 7) Pesquise sobre o `assert` e explique o código a seguir

# %%
nome = "João"

assert nome == "João", "Nome inesperado!"
assert nome == "Fernando", "Nome inesperado!"
